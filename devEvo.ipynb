# %%
import os
import sys
import pandas as pd

import evo_helpers as hlp
import evo_constants as CTS

# %%
hlp.welcome()
# Out:
# Welcome to EvoMinig

# %%
#from importlib import reload
#reload(evo_helpers)

opt = hlp.option_menu()
# Out:
# Press 1 to continue with precharged example.
# Press 2 to continue with your own databases.

# %%
class Evomining:
    """This class creates an evomining object.
    Its methods permit to access to the evomining
    funtionality.
    """

    def __init__(self, centralDB,evo_genomesDB, nat_prodsDB):
        self.central = centralDB
        self.genomesDB = evo_genomesDB
        self.nat_prods = nat_prodsDB

# %%
## obtener las bases de datos del usuario

#from importlib import reload
#reload(evo_helpers)

## option 1 precharged example:
if opt == 1:
    hlp.make_all_evo_headers(CTS.EXMPL_DB["genomes"],
                                 CTS.EXMPL_DB["rast_ids"])
    hlp.join_evo_headers_files()
    hlp.remove_evo_headers_files()
    
    evo_genomes_path = CTS.EVO_GENOMES_DB
    
    #evomining = EvoMining(cts.EXML_DB["central"],
    #                      cts.EXMPL_DB["genomes"],
    #                      cts.EXMPL_DB["nat_prods"])
    #evomining.run()
## option 2 user databases:
else: 
    user_dbs = hlp.get_dbs()
    hlp.make_all_evo_headers(user_dbs["genomes"], 
                             user_dbs["rast_ids"])
    hlp.join_evo_headers_files()
    hlp.remove_evo_headers_files()
    
    user_dbs["genomes"] = CTS.EVO_GENOMES_DB
    
    evomining = EvoMining(user_dbs["central"],
                         user_dbs["genomes"],
                         user_dbs["nat_prods"])
    #evomining.run()

#evomining.run()

# %% [markdown]
# ## Obtener los archivos .faa con los encabezados en formato evomining:
# ### Los nuevos .faa individuales se guardan en data/aux_data/  (se borran una vez utilizados)
# ### La base de datos con encabezados de evomining se guarda en /data/data_bases/evo_genomes_db/

# %%
#from importlib import reload
#reload(evo_helpers)

genomes_db = "/home/luisyovanny/.evo/dev_Evo/data/data_bases/example/genomes/los17"
Rast_ids = "/home/luisyovanny/.evo/dev_Evo/data/data_bases/example/genomes/los17Rast.ids"
hlp.make_all_evo_headers(genomes_db, Rast_ids)
hlp.join_evo_headers_files()
#hlp.remove_evo_headers_files()

# %% [markdown]
# ## Aplicar makeblastdb a las bases de datos que necesitaremos:

# %%
hlp.makeblast_db(CTS.EVO_GENOMES_DB)

# %%
hlp.makeblast_db(CTS.EXMPL_DB["central"])

# %%
hlp.makeblast_db(CTS.EXMPL_DB["nat_prods"])

# %% [markdown]
# ## Obtener los blastp entre la base de datos central vs la base de datos de genomas:

# %%
blastdb_path = CTS.BLASTDBs_PATH + 'evo_genomes_db_blastdb/'
            
hlp.apply_blastp(CTS.EXMPL_DB["central"], blastdb_path)

# %%
CTS.EVO_GENOMES_DB
# Out:
# '/home/luisyovanny/.evo/dev_Evo/data/data_bases/evo_genomes_db/'

# %% [markdown]
# ## Obtener los blastp entre la base de datos de genomas vs la base de datos central:

# %%
blastdb_path = CTS.BLASTDBs_PATH + 'central_blastdb/'
            
hlp.apply_blastp(CTS.EVO_GENOMES_DB, blastdb_path)

# %% [markdown]
# ## Obtener los BBH:

# %% [markdown]
# ### Obtener los mejores elementos únicos del blast de metabolismo central vs genomas:
# ### Estos se guardarán en un diccionario de la forma:
# ### { enzima_i : mejor_copia_en_el_organismo_k }
# ### donde i recorre todas las enzimas en el metabolismo central, y k recorre todos los genomas.
# ### - Considerar solo con bitscore >= 100 e E_value < 0.001

# %%
df1 = pd.read_csv('/home/luisyovanny/.evo/dev_Evo/data/data_bases/blastp/central_to_genomes/central_to_genomes.blast', sep = "\t", names = CTS.BLAST_COLS)

# %%
central_enzimes = df1['query'].unique() ##Lista con las enzimas del metabolismo central
genomes = hlp.dict_ids_to_names_genomes(CTS.EXMPL_DB["rast_ids"]) ## Diccio con los genomas de la base de genomas

# %%
central_enzimes
# Out:
# array(['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#        '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#        '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#        '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#        '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#        '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#        '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none'],
#       dtype=object)

# %%
genomes.keys()
# Out:
# dict_keys(['1156913.7', '169133.3', '290340.24', '367928.21', '442563.11', '446462.15', '452863.24', '649831.6', '6666666.104540', '6666666.111158', '6666666.111572', '6666666.112811', '6666666.146813', '6666666.146852', '6666666.146872', '749927.13', '930171.11'])

# %%
#definimos el diccionario que será la salida:
unique_in_first_blast = dict()
#inicializamos el diccionario tomando por claves todas las enzimas
# y por el momento asignando por valores listas vacías:
for enzime in central_enzimes:
    unique_in_first_blast[enzime] = []
    
#definimos una lista auxiliar que nos permitirá quedarnos con la mejor
# copia de la enzima presente en cada organismo 

#aux_list = list()
for enzime in central_enzimes:
    for genome_id in genomes.keys():
        aux_list = []
        if genome_id != "6666666.385189":
            for index in range(len(df1)):
                if (aux_list == []):
                    if ((enzime == df1["query"][index])&(genome_id in df1["subject"][index])):
                        aux_list = list(df1.iloc[index])
                    else:
                        continue
                else:
                    if ((enzime == df1["query"][index]) & (genome_id in df1["subject"][index]) & (df1["bitscore"][index] > aux_list[11])):
                        aux_list = list(df1.iloc[index])
            if aux_list != []:  
                unique_in_first_blast[enzime].append(aux_list)

# %%
unique_in_first_blast["3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none"]
# Out:
# [['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|1156913.7.7342|1156913.7|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#   67.769,
#   363,
#   116,
#   1,
#   1,
#   363,
#   13,
#   374,
#   3.0300000000000004e-179,
#   503.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|169133.3.2262|169133.3|LAB|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Citricoccus_sp_CH26_LAB',
#   68.32,
#   363,
#   115,
#   0,
#   1,
#   363,
#   12,
#   374,
#   0.0,
#   524.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|290340.24.1033|290340.24|NC_008711.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_aurescens_TC1_NC_008711.1',
#   67.493,
#   363,
#   118,
#   0,
#   1,
#   363,
#   12,
#   374,
#   0.0,
#   519.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|367928.21.407|367928.21|NC_008618.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#   57.297,
#   370,
#   151,
#   2,
#   1,
#   363,
#   11,
#   380,
#   8.969999999999999e-152,
#   433.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|442563.11.458|442563.11|AD011|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_animalis_subsp._lactis_AD011',
#   53.243,
#   370,
#   166,
#   2,
#   1,
#   363,
#   10,
#   379,
#   1.53e-142,
#   409.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|446462.15.520|446462.15|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#   66.942,
#   363,
#   119,
#   1,
#   1,
#   363,
#   16,
#   377,
#   0.0,
#   514.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|452863.24.923|452863.24|NC_011886.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#   68.32,
#   363,
#   115,
#   0,
#   1,
#   363,
#   12,
#   374,
#   0.0,
#   524.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|649831.6.513|649831.6|NC_021191.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._N902-109_NC_021191.1',
#   62.81,
#   363,
#   135,
#   0,
#   1,
#   363,
#   11,
#   373,
#   4.499999999999999e-170,
#   479.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.104540.2193|6666666.104540|AOHO01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#   67.769,
#   363,
#   116,
#   1,
#   1,
#   363,
#   13,
#   374,
#   0.0,
#   521.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.111158.8940|6666666.111158|NC_0131311|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#   73.003,
#   363,
#   98,
#   0,
#   1,
#   363,
#   10,
#   372,
#   0.0,
#   564.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.111572.2478|6666666.111572|NC_0094801|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#   64.641,
#   362,
#   126,
#   2,
#   1,
#   362,
#   302,
#   661,
#   1.79e-158,
#   460.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.112811.7991|6666666.112811|JOEF01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Allokutzneria_albata_JOEF01',
#   67.218,
#   363,
#   118,
#   1,
#   1,
#   363,
#   16,
#   377,
#   0.0,
#   513.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.146813.572|6666666.146813|NC_014550.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#   61.708,
#   363,
#   139,
#   0,
#   1,
#   363,
#   11,
#   373,
#   6.15e-169,
#   476.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.146852.774|6666666.146852|NC_002935.2|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#   61.326,
#   362,
#   139,
#   1,
#   1,
#   362,
#   11,
#   371,
#   7.62e-167,
#   471.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|6666666.146872.438|6666666.146872|NC_017803.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._SE50/110_NC_017803.1',
#   60.055,
#   363,
#   145,
#   0,
#   1,
#   363,
#   12,
#   374,
#   1.28e-166,
#   471.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|749927.13.8695|749927.13|NC_014318.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#   68.871,
#   363,
#   112,
#   1,
#   1,
#   363,
#   12,
#   373,
#   0.0,
#   527.0],
#  ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#   'gi|930171.11.818|930171.11|NC_015145.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#   67.218,
#   363,
#   119,
#   0,
#   1,
#   363,
#   12,
#   374,
#   0.0,
#   518.0]]

# %%
total = 0
for enz in central_enzimes:
        total = total + len(unique_in_first_blast[enz])
total
# Out:
# 119

# %% [markdown]
# ### NOTA: En la base de datos de genomas está de más el genoma con id = 6666666.385189

# %% [markdown]
# Unique de Genomes vs EF:

# %%
df2 = pd.read_csv('/home/luisyovanny/.evo/dev_Evo/data/data_bases/blastp/genomes_to_central/genomes_to_central.blast', sep = "\t", names = CTS.BLAST_COLS )

# %%
df2.head()
# Out:
#                                                query  \
# 0  gi|169133.3.1663|169133.3|LAB|Homoserine_dehyd...
# 1  gi|169133.3.2262|169133.3|LAB|Phosphoserine_am...
# 2  gi|169133.3.2262|169133.3|LAB|Phosphoserine_am...
# 3  gi|169133.3.2262|169133.3|LAB|Phosphoserine_am...
# 4  gi|169133.3.2437|169133.3|LAB|putative_2-hydro...
#
#                                              subject  pc_identity  aln_length  \
# 0  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...       37.778          45
# 1  3PGA_AMINOACIDS|2|Phosphoserine_aminotransfera...       68.320         363
# 2  3PGA_AMINOACIDS|2|Phosphoserine_aminotransfera...       64.785         372
# 3  3PGA_AMINOACIDS|2|Phosphoserine_aminotransfera...       61.202         366
# 4  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...       53.261          92
#
#    mismatches  gaps_opened  query_start  query_end  subject_start  \
# 0          28            0          342        386            442
# 1         115            0           12        374              1
# 2         130            1            3        374              6
# 3         141            1            7        372              6
# 4          43            0          211        302            195
#
#    subject_end        e_value  bitscore
# 0          486   3.230000e-06      37.7
# 1          363   0.000000e+00     524.0
# 2          376   0.000000e+00     504.0
# 3          370  3.710000e-171     473.0
# 4          286   3.370000e-21      82.0

# %%
len(genomes.keys())
# Out:
# 17

# %%
#definimos el diccionario que será la salida:
unique_in_second_blast = dict()
#inicializamos el diccionario tomando por claves todas las enzimas
# y por el momento asignando por valores listas vacías:
for genome_id in genomes.keys():
    if genome_id != "6666666.385189":
        unique_in_second_blast[genome_id] = []
    else:
        continue

#definimos una lista auxiliar que nos permitirá quedarnos con la mejor
# copia de la enzima presente en cada organismo 


for genome_id in genomes.keys():
    if genome_id != "6666666.385189":
        for enzime in central_enzimes:
            aux_list = []
            for index in range(len(df2)):
                if (aux_list == []):
                    if ((genome_id in df2["query"][index])&(enzime in df2["subject"][index])):
                        aux_list = list(df2.iloc[index])
                    else:
                        continue
                else:
                    if ((genome_id in df2["query"][index]) & (enzime in df2["subject"][index]) & (df2["bitscore"][index] > aux_list[11])):
                    
                        aux_list = list(df2.iloc[index])
            if aux_list != []:  
                unique_in_second_blast[genome_id].append(aux_list)

# %% [markdown]
# ### Prueba de bio.genbank package:

# %%
from taxonomy_ranks import TaxonomyRanks

# %%
taxa_name = 'Actinomadura hibisca'

rank_taxon = TaxonomyRanks(taxa_name)
# Out:
# NCBI database not present yet (first time used?)
# Downloading taxdump.tar.gz from NCBI FTP site (via HTTP)...
# Done. Parsing...
# Loading node names...
# 2609043 names loaded.
# 340117 synonyms loaded.
# Loading nodes...
# 2609043 nodes loaded.
# Linking nodes...
# Tree is loaded.
# Updating database: /home/luisyovanny/.etetoolkit/taxa.sqlite ...
#  2609000 generating entries...
# Inserting synonyms:      20000
# Uploading to /home/luisyovanny/.etetoolkit/taxa.sqlite
# Inserting synonyms:      340000
# Inserting taxids:       45000
# Inserting taxids:       2605000

# %%
type(rank_taxon)
# Out:
# taxonomy_ranks.get_taxonomy_rank_with_ete3_with_super_and_sub.TaxonomyRanks

# %%
rank_taxon.get_lineage_taxids_and_taxanames()

# %%
ranks = ('user_taxa', 'taxa_searched', 'superkingdom', 'kingdom', 'superphylum', 'phylum', 'subphylum', 'superclass', 'class', 'subclass', 'superorder', 'order', 'suborder', 'superfamily', 'family', 'subfamily', 'genus', 'subgenus', 'species')

# %%
for potential_taxid in rank_taxon.lineages:
     for rank in ranks:
         if rank in ('user_taxa', 'taxa_searched'):
             taxon = rank_taxon.lineages[potential_taxid][rank]
             print(potential_taxid, rank, taxon, sep='\t')
         else:
             taxon, taxid_of_taxon = rank_taxon.lineages[potential_taxid][rank]
             print(potential_taxid, rank, taxon, taxid_of_taxon, sep='\t')
# Out:
# 68565	user_taxa	Actinomadura hibisca
# 68565	taxa_searched	Actinomadura hibisca
# 68565	superkingdom	Bacteria	2
# 68565	kingdom	NA	NA
# 68565	superphylum	NA	NA
# 68565	phylum	Actinomycetota	201174
# 68565	subphylum	NA	NA
# 68565	superclass	NA	NA
# 68565	class	Actinomycetes	1760
# 68565	subclass	NA	NA
# 68565	superorder	NA	NA
# 68565	order	Streptosporangiales	85012
# 68565	suborder	NA	NA
# 68565	superfamily	NA	NA
# 68565	family	Thermomonosporaceae	2012
# 68565	subfamily	NA	NA
# 68565	genus	Actinomadura	1988
# 68565	subgenus	NA	NA
# 68565	species	Actinomadura hibisca	68565

# %% [markdown]
# ## Probar helpers para BBH:
# **<center>1.- best_hit_central_to_orgs:</center>**

# %%
import evo_helpers as hlp
import evo_constants as CTS

# %%
blast_File = '/home/luisyovanny/.evo/dev_Evo/data/data_bases/blastp/central_to_genomes/central_to_genomes.blast'
rast_Ids = CTS.EXMPL_DB["rast_ids"]

# %%
#Crea el archivo central_to_orgs_bh.uniq:
hlp.best_hit_central_to_orgs(blast_File)

# %%
hlp.ids_to_names_genomes_file(rast_Ids)

# %% [markdown]
# ### best_hit_central_to_genomes está bien!

# %%
def make_central_file_info():
    """This function creates a file with the names of all
    the elements in central_db.
    """
    central_fasta_file_path = CTS.EXMPL_DB["central"] + "central.fasta"
    output_path = CTS.BBH_aux_files + "central_enzimes.txt"
    with open(central_fasta_file_path,"r") as fasta_file:
        with open(output_path, "w") as output:
            for line in fasta_file:
                if ">" in line:
                    Line = line.split(">")[1]
                    output.write(Line)
    return

make_central_file_info()

# %%
def ids_to_names_genomes_file(file_rast_ids):
    """ This function returns a file with the genome id's as keys
    and the genome's names as values. The input file_rast_ids is the Rast.ids
    file within the genomes' database.
    """
    
    
    output_path = CTS.BBH_aux_files + "ids_to_orgs_names.txt"
    with open(file_rast_ids, "r") as file:
        with open(output_path, "w") as output:
            for line in file:
                Line = line.split("\t")[1] + "-->" + line.split("\t")[2]
                output.write(Line)
            
    return 
rast_ids_File = CTS.EXMPL_DB["rast_ids"]
ids_to_names_genomes_file(rast_ids_File)

# %% [markdown]
# # Por hacer:
# - Agregar una parte en la que se creen todos los archivos auxiliares al comienzo de la rutina, para que estén disponibles en las subrutinas.

# %% [markdown]
# ## Prueba best hit 1 con archivos:

# %%
def best_hit_central_to_orgs(blast_file):
    """ This function will obtain the best hit from central to organisms. Its output 
    is a file with these hits. From the output we will obtain the expanded families.
    """
    
    # Charge the dataframe with the blastp file:
    df = pd.read_csv(blast_file, sep = '\t', names = CTS.BLAST_COLS)
    
    #Obtain the different central enzimes:
    #central_enzimes = df['query'].unique()
    
    #Files with the enzimes and orgs info:
    central_enzimes_file = CTS.BBH_aux_files + 'central_enzimes.txt'
    central_enzimes = []
    with open(central_enzimes_file, "r") as central_file:
        for line in central_file:
            if line:
                central_enzimes.append(line.rstrip("\n"))
    
    ids_to_orgs_names_file = CTS.BBH_aux_files + 'ids_to_orgs_names.txt'
    genomes = dict()
    with open(ids_to_orgs_names_file, "r") as orgs_file:
        for line in orgs_file:
            if line:
                key = line.split("-->")[0]
                value = line.split("-->")[1]
                genomes[key] = value
    
    #Obtain a dictionary of the form {genome_id: "organism_name"}
    #genomes = dict_ids_to_names_genomes(rast_ids)
    
    #Define and initialize the output dictionary:
    unique_central_to_genomes = dict()
    for enzime in central_enzimes:
        unique_central_to_genomes[enzime] = []
        
    # Finding the best hit:
    for enzime in central_enzimes:
        for genome_id in genomes.keys():
            aux_list = []
            if genome_id != "6666666.385189":
                for index in range(len(df)):
                    if (aux_list == []):
                        if ((enzime == df["query"][index])&(genome_id in df["subject"][index])):
                            aux_list = list(df.iloc[index])
                        else:
                            continue
                    else:
                        if ((enzime == df["query"][index]) & (genome_id in df["subject"][index]) & (df["bitscore"][index] > aux_list[11])):
                            aux_list = list(df.iloc[index])
                if aux_list != []:  
                    unique_central_to_genomes[enzime].append(aux_list)
     
    return unique_central_to_genomes

# %%
test = best_hit_central_to_orgs(blast_File)
tot = 0
for enz in test:
    tot += len(test[enz])
tot
# Out:
# 119

# %%
def best_hit_central_to_orgs_2(blast_file):
    """ This function will obtain the best hit from central to organisms. Its output 
    is a file with these hits. From the output we will obtain the expanded families.
    """
    
    # Charge the dataframe with the blastp file:
    df = pd.read_csv(blast_file, sep = '\t', names = CTS.BLAST_COLS)
    
    ### SE NECESITA QUE LOS ARCHIVOS AUXILIARES ESTÉN CREADOS ###
    #Files with the enzimes and orgs info:
    
    # Make a list with the enzimes:
    central_enzimes_file = CTS.BBH_aux_files + 'central_enzimes.txt'
    central_enzimes = []
    with open(central_enzimes_file, "r") as central_file:
        for line in central_file:
            if line:
                central_enzimes.append(line.rstrip("\n"))
    
    
    # Make a dictionary with the ids and names of organisms:
    ids_to_orgs_names_file = CTS.BBH_aux_files + 'ids_to_orgs_names.txt'
    genomes = dict()
    with open(ids_to_orgs_names_file, "r") as orgs_file:
        for line in orgs_file:
            if line:
                key = line.split("-->")[0]
                value = line.split("-->")[1]
                genomes[key] = value
    
    
    
    #Define and initialize the output dictionary:
    unique_central_to_genomes = dict()
    for enzime in central_enzimes:
        unique_central_to_genomes[enzime] = []
        
    # Finding the best hit:
    for enzime in central_enzimes:
        for genome_id in genomes.keys():
            aux_list = []
            
            for index in range(len(df)):
                if (aux_list == []):
                    if ((enzime == df["query"][index])&(genome_id in df["subject"][index])):
                        aux_list = list(df.iloc[index])
                    else:
                        continue
                else:
                    if ((enzime == df["query"][index]) & (genome_id in df["subject"][index]) & (df["bitscore"][index] > aux_list[11])):
                        aux_list = list(df.iloc[index])
            if aux_list != []:  
                unique_central_to_genomes[enzime].append(aux_list)
     
    return unique_central_to_genomes

# %%
best_hit_central_to_orgs_2(blast_File)
# Out:
# {'3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu': [['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|1156913.7.6305|1156913.7|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    59.203,
#    527,
#    214,
#    1,
#    1,
#    526,
#    1,
#    527,
#    0.0,
#    613.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|169133.3.2692|169133.3|LAB|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Citricoccus_sp_CH26_LAB',
#    46.183,
#    524,
#    280,
#    2,
#    1,
#    523,
#    1,
#    523,
#    2.16e-155,
#    455.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|290340.24.2545|290340.24|NC_008711.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    49.049,
#    526,
#    267,
#    1,
#    6,
#    530,
#    5,
#    530,
#    2.0600000000000003e-161,
#    470.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|367928.21.1188|367928.21|NC_008618.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    34.098,
#    305,
#    182,
#    6,
#    7,
#    299,
#    6,
#    303,
#    1.04e-41,
#    155.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|442563.11.829|442563.11|AD011|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    36.749,
#    283,
#    171,
#    3,
#    15,
#    292,
#    13,
#    292,
#    3.03e-46,
#    167.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|446462.15.6083|446462.15|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    60.338,
#    532,
#    209,
#    2,
#    1,
#    530,
#    1,
#    532,
#    0.0,
#    595.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|452863.24.2320|452863.24|NC_011886.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    49.43,
#    526,
#    265,
#    1,
#    6,
#    530,
#    3,
#    528,
#    7.31e-164,
#    476.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|649831.6.6869|649831.6|NC_021191.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._N902-109_NC_021191.1',
#    52.408,
#    519,
#    244,
#    2,
#    7,
#    522,
#    3,
#    521,
#    6.7300000000000004e-167,
#    484.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.104540.4265|6666666.104540|AOHO01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    59.203,
#    527,
#    214,
#    1,
#    1,
#    526,
#    1,
#    527,
#    0.0,
#    612.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.111158.7934|6666666.111158|NC_0131311|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    54.685,
#    523,
#    237,
#    0,
#    4,
#    526,
#    7,
#    529,
#    3.6999999999999997e-180,
#    518.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.111572.1121|6666666.111572|NC_0094801|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    49.904,
#    521,
#    261,
#    0,
#    6,
#    526,
#    3,
#    523,
#    1.55e-162,
#    473.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.112811.5461|6666666.112811|JOEF01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Allokutzneria_albata_JOEF01',
#    58.317,
#    523,
#    217,
#    1,
#    1,
#    522,
#    1,
#    523,
#    0.0,
#    580.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.146813.1460|6666666.146813|NC_014550.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    49.522,
#    523,
#    263,
#    1,
#    1,
#    523,
#    1,
#    522,
#    3.7e-170,
#    492.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.146852.1090|6666666.146852|NC_002935.2|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    79.623,
#    530,
#    108,
#    0,
#    1,
#    530,
#    1,
#    530,
#    0.0,
#    847.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|6666666.146872.7282|6666666.146872|NC_017803.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    51.145,
#    524,
#    248,
#    3,
#    8,
#    529,
#    4,
#    521,
#    6.18e-171,
#    494.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|749927.13.1727|749927.13|NC_014318.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    59.586,
#    532,
#    213,
#    2,
#    1,
#    530,
#    1,
#    532,
#    0.0,
#    620.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu',
#    'gi|930171.11.2378|930171.11|NC_015145.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    49.43,
#    526,
#    265,
#    1,
#    6,
#    530,
#    3,
#    528,
#    4.469999999999999e-165,
#    479.0]],
#  '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub': [['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|1156913.7.7552|1156913.7|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    40.769,
#    260,
#    144,
#    3,
#    73,
#    324,
#    85,
#    342,
#    6.64e-47,
#    162.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|169133.3.2692|169133.3|LAB|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Citricoccus_sp_CH26_LAB',
#    35.294,
#    255,
#    150,
#    3,
#    74,
#    320,
#    68,
#    315,
#    1.8e-37,
#    141.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|290340.24.1979|290340.24|NC_008711.1|Glyoxylate_reductase_(EC_1.1.1.79)_/_Glyoxylate_reductase_(EC_1.1.1.26)_/_Hydroxypyruvate_reductase_(EC_1.1.1.81)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    34.154,
#    325,
#    186,
#    9,
#    6,
#    315,
#    3,
#    314,
#    4.04e-37,
#    135.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|367928.21.1188|367928.21|NC_008618.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    29.644,
#    253,
#    145,
#    7,
#    85,
#    315,
#    81,
#    322,
#    2.67e-23,
#    100.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|442563.11.379|442563.11|AD011|Phosphoglycerate_dehydrogenase|Bifidobacterium_animalis_subsp._lactis_AD011',
#    34.583,
#    240,
#    135,
#    5,
#    82,
#    311,
#    100,
#    327,
#    4.33e-28,
#    112.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|446462.15.4214|446462.15|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    40.288,
#    278,
#    149,
#    5,
#    39,
#    304,
#    33,
#    305,
#    3.35e-41,
#    146.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|452863.24.89|452863.24|NC_011886.1|Glyoxylate_reductase_(EC_1.1.1.79)_/_Glyoxylate_reductase_(EC_1.1.1.26)_/_Hydroxypyruvate_reductase_(EC_1.1.1.81)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    35.276,
#    326,
#    183,
#    9,
#    6,
#    316,
#    3,
#    315,
#    1.24e-40,
#    145.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|649831.6.6869|649831.6|NC_021191.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._N902-109_NC_021191.1',
#    38.132,
#    257,
#    144,
#    3,
#    74,
#    322,
#    65,
#    314,
#    9.169999999999999e-41,
#    150.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.104540.4265|6666666.104540|AOHO01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    38.039,
#    255,
#    143,
#    3,
#    74,
#    320,
#    69,
#    316,
#    1.46e-39,
#    146.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.111158.7934|6666666.111158|NC_0131311|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    36.471,
#    255,
#    147,
#    4,
#    74,
#    320,
#    72,
#    319,
#    6.21e-33,
#    128.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.111572.1121|6666666.111572|NC_0094801|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    35.686,
#    255,
#    149,
#    3,
#    74,
#    320,
#    66,
#    313,
#    7.95e-37,
#    139.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.112811.1464|6666666.112811|JOEF01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Allokutzneria_albata_JOEF01',
#    41.606,
#    274,
#    152,
#    4,
#    56,
#    323,
#    67,
#    338,
#    4.08e-56,
#    186.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.146813.1460|6666666.146813|NC_014550.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    36.187,
#    257,
#    149,
#    3,
#    72,
#    320,
#    66,
#    315,
#    1.8e-41,
#    152.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.146852.1090|6666666.146852|NC_002935.2|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    33.548,
#    310,
#    187,
#    6,
#    23,
#    320,
#    14,
#    316,
#    1.88e-35,
#    135.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|6666666.146872.7282|6666666.146872|NC_017803.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    37.956,
#    274,
#    153,
#    4,
#    57,
#    320,
#    46,
#    312,
#    7.03e-40,
#    147.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|749927.13.1727|749927.13|NC_014318.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    35.691,
#    311,
#    181,
#    6,
#    22,
#    320,
#    13,
#    316,
#    1.05e-37,
#    141.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_2|Mtub',
#    'gi|930171.11.2378|930171.11|NC_015145.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    36.187,
#    257,
#    149,
#    3,
#    72,
#    320,
#    64,
#    313,
#    2.3700000000000002e-35,
#    135.0]],
#  '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub': [['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|1156913.7.6305|1156913.7|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    64.381,
#    525,
#    186,
#    1,
#    4,
#    527,
#    7,
#    531,
#    0.0,
#    645.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|169133.3.2692|169133.3|LAB|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Citricoccus_sp_CH26_LAB',
#    50.38,
#    526,
#    258,
#    2,
#    4,
#    527,
#    6,
#    530,
#    4.01e-176,
#    508.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|290340.24.2545|290340.24|NC_008711.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    49.43,
#    526,
#    266,
#    0,
#    2,
#    527,
#    4,
#    529,
#    9.35e-171,
#    494.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|367928.21.1188|367928.21|NC_008618.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    30.492,
#    305,
#    203,
#    5,
#    2,
#    299,
#    4,
#    306,
#    1.42e-38,
#    146.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|442563.11.829|442563.11|AD011|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    31.353,
#    303,
#    197,
#    4,
#    3,
#    297,
#    1,
#    300,
#    5.5599999999999995e-40,
#    150.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|446462.15.6083|446462.15|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    65.465,
#    527,
#    181,
#    1,
#    2,
#    527,
#    5,
#    531,
#    0.0,
#    622.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|452863.24.2320|452863.24|NC_011886.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    49.905,
#    527,
#    264,
#    0,
#    1,
#    527,
#    1,
#    527,
#    4.0400000000000006e-173,
#    499.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|649831.6.6869|649831.6|NC_021191.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._N902-109_NC_021191.1',
#    55.787,
#    527,
#    230,
#    2,
#    4,
#    527,
#    3,
#    529,
#    8.28e-178,
#    511.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.104540.4265|6666666.104540|AOHO01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    64.381,
#    525,
#    186,
#    1,
#    4,
#    527,
#    7,
#    531,
#    0.0,
#    643.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.111158.7934|6666666.111158|NC_0131311|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    58.969,
#    524,
#    215,
#    0,
#    4,
#    527,
#    10,
#    533,
#    0.0,
#    566.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.111572.1121|6666666.111572|NC_0094801|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    52.273,
#    528,
#    252,
#    0,
#    1,
#    528,
#    1,
#    528,
#    1.17e-175,
#    506.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.112811.5461|6666666.112811|JOEF01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Allokutzneria_albata_JOEF01',
#    66.151,
#    517,
#    174,
#    1,
#    4,
#    519,
#    7,
#    523,
#    0.0,
#    637.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.146813.1460|6666666.146813|NC_014550.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    51.938,
#    516,
#    248,
#    0,
#    4,
#    519,
#    6,
#    521,
#    0.0,
#    534.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.146852.1090|6666666.146852|NC_002935.2|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    67.562,
#    521,
#    169,
#    0,
#    4,
#    524,
#    7,
#    527,
#    0.0,
#    688.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|6666666.146872.7282|6666666.146872|NC_017803.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    55.725,
#    524,
#    225,
#    2,
#    5,
#    527,
#    4,
#    521,
#    0.0,
#    538.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|749927.13.1727|749927.13|NC_014318.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    65.341,
#    528,
#    182,
#    1,
#    2,
#    528,
#    5,
#    532,
#    0.0,
#    658.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_3|Mtub',
#    'gi|930171.11.2378|930171.11|NC_015145.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    50.854,
#    527,
#    259,
#    0,
#    1,
#    527,
#    1,
#    527,
#    1.0999999999999999e-174,
#    504.0]],
#  '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe': [['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|1156913.7.6305|1156913.7|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    53.7,
#    527,
#    243,
#    1,
#    3,
#    528,
#    5,
#    531,
#    0.0,
#    545.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|169133.3.2692|169133.3|LAB|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Citricoccus_sp_CH26_LAB',
#    62.879,
#    528,
#    195,
#    1,
#    3,
#    529,
#    4,
#    531,
#    0.0,
#    686.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|290340.24.2545|290340.24|NC_008711.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    67.362,
#    527,
#    172,
#    0,
#    2,
#    528,
#    3,
#    529,
#    0.0,
#    715.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|367928.21.1188|367928.21|NC_008618.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    32.459,
#    305,
#    197,
#    4,
#    3,
#    300,
#    4,
#    306,
#    6.57e-43,
#    158.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|442563.11.829|442563.11|AD011|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    33.77,
#    305,
#    191,
#    5,
#    5,
#    302,
#    2,
#    302,
#    3.6e-43,
#    159.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|446462.15.6083|446462.15|NC_021252.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    56.061,
#    528,
#    231,
#    1,
#    2,
#    528,
#    4,
#    531,
#    0.0,
#    541.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|452863.24.2320|452863.24|NC_011886.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    65.779,
#    526,
#    180,
#    0,
#    3,
#    528,
#    2,
#    527,
#    0.0,
#    700.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|649831.6.6869|649831.6|NC_021191.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._N902-109_NC_021191.1',
#    61.48,
#    527,
#    200,
#    2,
#    5,
#    528,
#    3,
#    529,
#    0.0,
#    606.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.104540.4265|6666666.104540|AOHO01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    53.89,
#    527,
#    242,
#    1,
#    3,
#    528,
#    5,
#    531,
#    0.0,
#    545.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.111158.7934|6666666.111158|NC_0131311|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    74.053,
#    528,
#    137,
#    0,
#    1,
#    528,
#    6,
#    533,
#    0.0,
#    769.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.111572.1121|6666666.111572|NC_0094801|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    64.259,
#    526,
#    188,
#    0,
#    3,
#    528,
#    2,
#    527,
#    0.0,
#    672.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.112811.5461|6666666.112811|JOEF01|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Allokutzneria_albata_JOEF01',
#    55.682,
#    528,
#    233,
#    1,
#    2,
#    528,
#    4,
#    531,
#    0.0,
#    563.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.146813.1460|6666666.146813|NC_014550.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    65.779,
#    526,
#    180,
#    0,
#    3,
#    528,
#    4,
#    529,
#    0.0,
#    718.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.146852.1090|6666666.146852|NC_002935.2|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    51.731,
#    520,
#    251,
#    0,
#    1,
#    520,
#    3,
#    522,
#    6.23e-177,
#    509.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|6666666.146872.7282|6666666.146872|NC_017803.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    60.496,
#    524,
#    200,
#    3,
#    6,
#    528,
#    4,
#    521,
#    0.0,
#    612.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|749927.13.1727|749927.13|NC_014318.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    53.321,
#    527,
#    245,
#    1,
#    3,
#    528,
#    5,
#    531,
#    0.0,
#    546.0],
#   ['3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_4|Scoe',
#    'gi|930171.11.2378|930171.11|NC_015145.1|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    66.16,
#    526,
#    178,
#    0,
#    3,
#    528,
#    2,
#    527,
#    0.0,
#    702.0]],
#  '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none': [['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|1156913.7.7342|1156913.7|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    62.634,
#    372,
#    137,
#    1,
#    1,
#    370,
#    1,
#    372,
#    1.49e-168,
#    476.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|169133.3.2262|169133.3|LAB|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Citricoccus_sp_CH26_LAB',
#    61.202,
#    366,
#    141,
#    1,
#    6,
#    370,
#    7,
#    372,
#    3.75e-167,
#    473.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|290340.24.1033|290340.24|NC_008711.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    62.466,
#    365,
#    136,
#    1,
#    6,
#    369,
#    7,
#    371,
#    3.56e-169,
#    478.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|367928.21.407|367928.21|NC_008618.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    54.233,
#    378,
#    165,
#    2,
#    1,
#    370,
#    1,
#    378,
#    2.83e-146,
#    420.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|442563.11.458|442563.11|AD011|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    49.598,
#    373,
#    180,
#    2,
#    6,
#    370,
#    5,
#    377,
#    2.18e-132,
#    384.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|446462.15.520|446462.15|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    63.636,
#    363,
#    132,
#    0,
#    7,
#    369,
#    12,
#    374,
#    4.53e-176,
#    495.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|452863.24.923|452863.24|NC_011886.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    61.096,
#    365,
#    141,
#    1,
#    6,
#    369,
#    7,
#    371,
#    1.06e-164,
#    466.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|649831.6.513|649831.6|NC_021191.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._N902-109_NC_021191.1',
#    53.639,
#    371,
#    171,
#    1,
#    1,
#    370,
#    1,
#    371,
#    7.34e-140,
#    403.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.104540.2193|6666666.104540|AOHO01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    62.634,
#    372,
#    137,
#    1,
#    1,
#    370,
#    1,
#    372,
#    1.37e-174,
#    491.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.111158.8940|6666666.111158|NC_0131311|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    60.109,
#    366,
#    145,
#    1,
#    6,
#    370,
#    5,
#    370,
#    2.3900000000000003e-164,
#    465.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.111572.2478|6666666.111572|NC_0094801|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    59.401,
#    367,
#    148,
#    1,
#    6,
#    372,
#    297,
#    662,
#    2.37e-147,
#    432.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.112811.7991|6666666.112811|JOEF01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Allokutzneria_albata_JOEF01',
#    64.011,
#    364,
#    131,
#    0,
#    7,
#    370,
#    12,
#    375,
#    3.65e-176,
#    495.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.146813.572|6666666.146813|NC_014550.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    59.452,
#    365,
#    147,
#    1,
#    7,
#    370,
#    7,
#    371,
#    6.460000000000001e-161,
#    456.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.146852.774|6666666.146852|NC_002935.2|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    81.6,
#    375,
#    69,
#    0,
#    1,
#    375,
#    1,
#    375,
#    0.0,
#    646.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|6666666.146872.438|6666666.146872|NC_017803.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    52.603,
#    365,
#    172,
#    1,
#    7,
#    370,
#    8,
#    372,
#    5.71e-137,
#    396.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|749927.13.8695|749927.13|NC_014318.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    62.534,
#    371,
#    138,
#    1,
#    1,
#    370,
#    1,
#    371,
#    7.59e-172,
#    484.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_1|none',
#    'gi|930171.11.818|930171.11|NC_015145.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    61.096,
#    365,
#    141,
#    1,
#    6,
#    369,
#    7,
#    371,
#    1.55e-165,
#    468.0]],
#  '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none': [['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|1156913.7.7342|1156913.7|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    67.027,
#    370,
#    122,
#    0,
#    7,
#    376,
#    5,
#    374,
#    0.0,
#    516.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|169133.3.2262|169133.3|LAB|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Citricoccus_sp_CH26_LAB',
#    64.785,
#    372,
#    130,
#    1,
#    6,
#    376,
#    3,
#    374,
#    1.2e-179,
#    504.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|290340.24.1033|290340.24|NC_008711.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    60.976,
#    369,
#    143,
#    1,
#    9,
#    376,
#    6,
#    374,
#    3.3e-169,
#    478.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|367928.21.407|367928.21|NC_008618.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    56.053,
#    380,
#    159,
#    2,
#    5,
#    376,
#    1,
#    380,
#    2.3099999999999998e-150,
#    430.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|442563.11.458|442563.11|AD011|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    54.521,
#    376,
#    163,
#    2,
#    9,
#    376,
#    4,
#    379,
#    3.52e-144,
#    414.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|446462.15.520|446462.15|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    70.109,
#    368,
#    110,
#    0,
#    9,
#    376,
#    10,
#    377,
#    0.0,
#    537.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|452863.24.923|452863.24|NC_011886.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    59.892,
#    369,
#    147,
#    1,
#    9,
#    376,
#    6,
#    374,
#    1.6800000000000002e-164,
#    466.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|649831.6.513|649831.6|NC_021191.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._N902-109_NC_021191.1',
#    57.995,
#    369,
#    154,
#    1,
#    9,
#    376,
#    5,
#    373,
#    1.99e-152,
#    435.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.104540.2193|6666666.104540|AOHO01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    67.027,
#    370,
#    122,
#    0,
#    7,
#    376,
#    5,
#    374,
#    0.0,
#    532.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.111158.8940|6666666.111158|NC_0131311|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    63.686,
#    369,
#    133,
#    1,
#    9,
#    376,
#    4,
#    372,
#    8.41e-175,
#    492.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.111572.2478|6666666.111572|NC_0094801|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    60.976,
#    369,
#    143,
#    1,
#    7,
#    375,
#    294,
#    661,
#    1.14e-153,
#    449.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.112811.7991|6666666.112811|JOEF01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Allokutzneria_albata_JOEF01',
#    69.022,
#    368,
#    114,
#    0,
#    9,
#    376,
#    10,
#    377,
#    0.0,
#    542.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.146813.572|6666666.146813|NC_014550.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    59.249,
#    373,
#    151,
#    1,
#    5,
#    376,
#    1,
#    373,
#    3.7300000000000006e-167,
#    472.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.146852.774|6666666.146852|NC_002935.2|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    61.37,
#    365,
#    141,
#    0,
#    11,
#    375,
#    7,
#    371,
#    4.77e-165,
#    467.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|6666666.146872.438|6666666.146872|NC_017803.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    57.105,
#    373,
#    159,
#    1,
#    5,
#    376,
#    2,
#    374,
#    3.27e-152,
#    434.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|749927.13.8695|749927.13|NC_014318.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    66.938,
#    369,
#    122,
#    0,
#    8,
#    376,
#    5,
#    373,
#    0.0,
#    527.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_2|none',
#    'gi|930171.11.818|930171.11|NC_015145.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    61.518,
#    369,
#    141,
#    1,
#    9,
#    376,
#    6,
#    374,
#    1.53e-168,
#    476.0]],
#  '3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none': [['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|1156913.7.7342|1156913.7|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_orientalis_HCCB10007_NC_021252.1',
#    67.769,
#    363,
#    116,
#    1,
#    1,
#    363,
#    13,
#    374,
#    3.0300000000000004e-179,
#    503.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|169133.3.2262|169133.3|LAB|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Citricoccus_sp_CH26_LAB',
#    68.32,
#    363,
#    115,
#    0,
#    1,
#    363,
#    12,
#    374,
#    0.0,
#    524.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|290340.24.1033|290340.24|NC_008711.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_aurescens_TC1_NC_008711.1',
#    67.493,
#    363,
#    118,
#    0,
#    1,
#    363,
#    12,
#    374,
#    0.0,
#    519.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|367928.21.407|367928.21|NC_008618.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_adolescentis_ATCC_15703_NC_008618.1',
#    57.297,
#    370,
#    151,
#    2,
#    1,
#    363,
#    11,
#    380,
#    8.969999999999999e-152,
#    433.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|442563.11.458|442563.11|AD011|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Bifidobacterium_animalis_subsp._lactis_AD011',
#    53.243,
#    370,
#    166,
#    2,
#    1,
#    363,
#    10,
#    379,
#    1.53e-142,
#    409.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|446462.15.520|446462.15|NC_021252.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinosynnema_mirum_DSM_43827_NC_013093.1_NC_021252.1',
#    66.942,
#    363,
#    119,
#    1,
#    1,
#    363,
#    16,
#    377,
#    0.0,
#    514.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|452863.24.923|452863.24|NC_011886.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_chlorophenolicus_A6_NC_011886.1',
#    68.32,
#    363,
#    115,
#    0,
#    1,
#    363,
#    12,
#    374,
#    0.0,
#    524.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|649831.6.513|649831.6|NC_021191.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._N902-109_NC_021191.1',
#    62.81,
#    363,
#    135,
#    0,
#    1,
#    363,
#    11,
#    373,
#    4.499999999999999e-170,
#    479.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.104540.2193|6666666.104540|AOHO01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_decaplanina_DSM_44594_AOHO01',
#    67.769,
#    363,
#    116,
#    1,
#    1,
#    363,
#    13,
#    374,
#    0.0,
#    521.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.111158.8940|6666666.111158|NC_0131311|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Catenulispora_acidiphila_DSM_44928_NC_0131311',
#    73.003,
#    363,
#    98,
#    0,
#    1,
#    363,
#    10,
#    372,
#    0.0,
#    564.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.111572.2478|6666666.111572|NC_0094801|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Clavibacter_michiganensis_subsp._michiganensis_NCPPB_382_NC_0094801',
#    64.641,
#    362,
#    126,
#    2,
#    1,
#    362,
#    302,
#    661,
#    1.79e-158,
#    460.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.112811.7991|6666666.112811|JOEF01|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Allokutzneria_albata_JOEF01',
#    67.218,
#    363,
#    118,
#    1,
#    1,
#    363,
#    16,
#    377,
#    0.0,
#    513.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.146813.572|6666666.146813|NC_014550.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_arilaitensis_RE117_NC_014550.1',
#    61.708,
#    363,
#    139,
#    0,
#    1,
#    363,
#    11,
#    373,
#    6.15e-169,
#    476.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.146852.774|6666666.146852|NC_002935.2|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2',
#    61.326,
#    362,
#    139,
#    1,
#    1,
#    362,
#    11,
#    371,
#    7.62e-167,
#    471.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|6666666.146872.438|6666666.146872|NC_017803.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Actinoplanes_sp._SE50/110_NC_017803.1',
#    60.055,
#    363,
#    145,
#    0,
#    1,
#    363,
#    12,
#    374,
#    1.28e-166,
#    471.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|749927.13.8695|749927.13|NC_014318.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Amycolatopsis_mediterranei_U32_NC_014318.1',
#    68.871,
#    363,
#    112,
#    1,
#    1,
#    363,
#    12,
#    373,
#    0.0,
#    527.0],
#   ['3PGA_AMINOACIDS|2|Phosphoserine_aminotransferase_3|none',
#    'gi|930171.11.818|930171.11|NC_015145.1|Phosphoserine_aminotransferase_(EC_2.6.1.52)|Arthrobacter_phenanthrenivorans_Sphe3_NC_015145.1',
#    67.218,
#    363,
#    119,
#    0,
#    1,
#    363,
#    12,
#    374,
#    0.0,
#    518.0]]}

# %%
test2 = best_hit_central_to_orgs_2(blast_File)
tot1 = 0
for enz in test2:
    tot1 += len(test2[enz])
tot1
# Out:
# 119

# %%
li = list(df1.iloc[0])
li = [str(el) for el in li]
"\t".join(li)
# Out:
# '3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogenase_1|Cglu\tgi|6666666.146852.1090|6666666.146852|NC_002935.2|D-3-phosphoglycerate_dehydrogenase_(EC_1.1.1.95)|Corynebacterium_diphtheriae_NCTC_13129_NC_002935.2\t79.623\t530\t108\t0\t1\t530\t1\t530\t0.0\t847.0'

# %%
def best_hit_central_to_orgs_3(blast_file):
    """ This function will obtain the best hit from central to organisms. Its output 
    is a file with these hits. From the output we will obtain the expanded families.
    """
    
    # Charge the dataframe with the blastp file:
    df = pd.read_csv(blast_file, sep = '\t', names = CTS.BLAST_COLS)
    
    ### SE NECESITA QUE LOS ARCHIVOS AUXILIARES ESTÉN CREADOS ###
    #Files with the enzimes and orgs info:
    
    # Make a list with the enzimes:
    central_enzimes_file = CTS.BBH_aux_files + 'central_enzimes.txt'
    central_enzimes = []
    with open(central_enzimes_file, "r") as central_file:
        for line in central_file:
            if line:
                central_enzimes.append(line.rstrip("\n"))
    
    
    # Make a dictionary with the ids and names of organisms:
    ids_to_orgs_names_file = CTS.BBH_aux_files + 'ids_to_orgs_names.txt'
    genomes = dict()
    with open(ids_to_orgs_names_file, "r") as orgs_file:
        for line in orgs_file:
            if line:
                key = line.split("-->")[0]
                value = line.split("-->")[1]
                genomes[key] = value
    
    
    
    #Define and initialize the output dictionary:
    #unique_central_to_genomes = dict()
    #for enzime in central_enzimes:
    #    unique_central_to_genomes[enzime] = []
     
    # Path to best hits file:
    
    central_to_orgs_bh = CTS.BBH_aux_files + "central_to_orgs_BH.uniq"
    
    
    # Finding the best hit:
    best_hits_file = open(central_to_orgs_bh, "w")
    for enzime in central_enzimes:
        for genome_id in genomes.keys():
            aux_list = []
            
            for index in range(len(df)):
                if (aux_list == []):
                    if ((enzime == df["query"][index])&(genome_id in df["subject"][index])):
                        aux_list = list(df.iloc[index])
                    else:
                        continue
                else:
                    if ((enzime == df["query"][index]) & (genome_id in df["subject"][index]) & (df["bitscore"][index] > aux_list[11])):
                        aux_list = list(df.iloc[index])
            if aux_list != []: 
                line = ["{}\t".format(item) for item in aux_list]
                best_hits_file.writelines(line)
                best_hits_file.write("\n")
                
    best_hits_file.close() 
    #return unique_central_to_genomes
    return

# %%
best_hit_central_to_orgs_3(blast_File)

# %%
cadena = "Hola\ta\ntodos."

# %%
cadena

# %% [markdown]
# ### Prueba de escribir best hits segundo blast en un archivo:

# %%
def best_hit_orgs_to_central(blast_file):
    """ This function will obtain the best hit from organisms to central, i.e., 
    assigns to each position id of a blast hit the corresponding enzime that best 
    hits in that particular place.
    """
    
    #charge dataframe:
    df = pd.read_csv(blast_file, sep = '\t', names = CTS.BLAST_COLS, index_col = False)
    
    #Obtain dictionary with the copy id position to the line of blast
    
    uniq2 = dict()
    for index in df.index:
        actual_line = df.iloc[index]
        copy_id = actual_line["query"].split("|")[1]  #id of the hit position
        if copy_id in uniq2:
            if actual_line["bitscore"] > uniq2[copy_id][11]:
                uniq2[copy_id] = list(actual_line)
        else:
            if actual_line["bitscore"] > 0:
                uniq2[copy_id] = list(actual_line)
    
    
    # Write the file with the best hits:
    
    orgs_to_central_bh = CTS.BBH_aux_files + "orgs_to_central_BH.uniq"  #Agregar ruta a constantes
    best_hits_file = open(orgs_to_central_bh, "w")
     
    for key in uniq2:
        line = ["{}\t".format(item) for item in uniq2[key]] 
        best_hits_file.writelines(line)
        best_hits_file.write("\n")
    
    
    best_hits_file.close()
    return

# %%
path_second_blast = '/home/luisyovanny/.evo/dev_Evo/data/data_bases/blastp/genomes_to_central/genomes_to_central.blast'
hlp.best_hit_orgs_to_central(path_second_blast)

# %%
orgs_to_central_bh = CTS.BBH_aux_files + "orgs_to_central_BH.uniq"
DF1 = pd.read_csv(orgs_to_central_bh, sep = "\t", names = CTS.BLAST_COLS, index_col = False)

# %%
central_to_orgs_bh = CTS.BBH_aux_files + "central_to_orgs_BH.uniq"
DF2 = pd.read_csv(central_to_orgs_bh, sep = "\t", names = CTS.BLAST_COLS, index_col = False)

# %%
DF2.head()
# Out:
#                                                query  \
# 0  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...
# 1  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...
# 2  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...
# 3  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...
# 4  3PGA_AMINOACIDS|1|Phosphoglycerate_dehydrogena...
#
#                                              subject  pc_identity  aln_length  \
# 0  gi|1156913.7.6305|1156913.7|NC_021252.1|D-3-ph...       59.203         527
# 1  gi|169133.3.2692|169133.3|LAB|D-3-phosphoglyce...       46.183         524
# 2  gi|290340.24.2545|290340.24|NC_008711.1|D-3-ph...       49.049         526
# 3  gi|367928.21.1188|367928.21|NC_008618.1|D-3-ph...       34.098         305
# 4  gi|442563.11.829|442563.11|AD011|D-3-phosphogl...       36.749         283
#
#    mismatches  gaps_opened  query_start  query_end  subject_start  \
# 0         214            1            1        526              1
# 1         280            2            1        523              1
# 2         267            1            6        530              5
# 3         182            6            7        299              6
# 4         171            3           15        292             13
#
#    subject_end        e_value  bitscore
# 0          527   0.000000e+00     613.0
# 1          523  2.160000e-155     455.0
# 2          530  2.060000e-161     470.0
# 3          303   1.040000e-41     155.0
# 4          292   3.030000e-46     167.0

# %%
def bbh_detector(central_to_orgs_bhs, orgs_to_central_bhs):
    """ This function obtains the best bidirectional hits between
    the blast of central to organisms and organisms to central respectively.
    """

    # charge dataframes:
    
    df = pd.read_csv(central_to_orgs_bhs, sep = ' ', names = CTS.BLAST_COLS, index_col = False)
    
    df1 = pd.read_csv(orgs_to_central_bhs, sep = ' ', names = CTS.BLAST_COLS, index_col = False)
    
    # Write the file with the bbh:
    
    BBH_file = CTS.BBH_aux_files + "BBH.bbh"  #Agregar ruta a constantes
    bbh_file = open(BBH_file, "w")
     
    for indx in df1.index:
        copy_id = df1.iloc[indx]["query"].split("|")[1]
        enzime = df1.iloc[indx]["subject"]
        for indxx in df.index:
            if copy_id not in df.iloc[indxx]["subject"]:
                continue
            elif enzime not in df.iloc[indxx]["query"]:
                continue
            else:
                #bbh[copy_id] = enzime
                bbh_file.write(copy_id + " -> ")
                bbh_file.write(enzime +"\t")
                bbh_file.write(df1.iloc[indx]["query"]+"\n")
           
    
    bbh_file.close()
    return

# %%
cent_to_org_bh = CTS.BBH_aux_files + "central_to_orgs_BH.uniq"
org_to_cent_bh = CTS.BBH_aux_files + "orgs_to_central_BH.uniq"
hlp.bbh_detector(cent_to_org_bh, org_to_cent_bh)
#df1 = pd.read_csv(org_to_cent_bh, sep = ' ', names = CTS.BLAST_COLS, index_col =False)
# Out:
# /home/luisyovanny/.evo/dev_Evo/evo_helpers.py:576: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   enzime = df1.iloc[indx][1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 cent_to_org_bh = CTS.BBH_aux_files + "central_to_orgs_BH.uniq"
#       2 org_to_cent_bh = CTS.BBH_aux_files + "orgs_to_central_BH.uniq"
# ----> 3 hlp.bbh_detector(cent_to_org_bh, org_to_cent_bh)
#       4 #df1 = pd.read_csv(org_to_cent_bh, sep = ' ', names = CTS.BLAST_COLS, index_col =False)
#
# File ~/.evo/dev_Evo/evo_helpers.py:578, in bbh_detector(central_to_orgs_bhs, orgs_to_central_bhs)
#     576 enzime = df1.iloc[indx][1]
#     577 for indxx in list(df.index):
# --> 578     if copy_id not in df.iloc[indxx]["subject"]:
#     579         continue
#     580     elif enzime not in df.iloc[indxx]["query"]:
#
# TypeError: argument of type 'numpy.float64' is not iterable

# %%
#df1

# %%
import evo_helpers as hlp
bbh_detector(cent_to_org_bh, org_to_cent_bh)

# %% [markdown]
# ## Comparar los bbh contra los obtenidos en evomining:

# %%
BBH_mio = list()
BBH_mio_path = "/home/luisyovanny/.evo/dev_Evo/data/aux_data/bbh_aux_files/BBH.bbh"
bbh_mio = open(BBH_mio_path, 'r')
for line in bbh_mio:
    hit = line.split("\t")[0]
    BBH_mio.append(hit)


bbh_mio.close()
BBH_mio_set = set(BBH_mio)

# %%
BBH_evo = list()
BBH_evo_path = "/home/luisyovanny/.evo/dev_Evo/vueltalos17.blast.bbh"
bbh_evo = open(BBH_evo_path, 'r')
for line in bbh_evo:
    hit = line.split("\t")[0]
    BBH_evo.append(hit)


bbh_evo.close()
BBH_evo_set = set(BBH_evo)

# %%
BBH_evo_set == BBH_mio_set

# %%
#bbh_set

# %%
expanded_families_files = [x for x in os.listdir(CTS.EXPANDED_FAMS) if x.endswith(".fasta")]

# %%
expanded_families_files

# %%
blastdb_path = CTS.BLASTDBs_PATH + "nat_prods_blastdb/"
h = blastdb_path + blastdb_path.split("/")[-2]

# %%
h

# %%
blastdb_path = CTS.BLASTDBs_PATH + 'central_blastdb/'
h = blastdb_path + blastdb_path.split("/")[-2]
h

# %%
mibig_db = CTS.MIBiG_NAT_PRODS_DB + "nat_prods.fasta"
mibig_file = open(mibig_db, "r")
line = mibig_file.readline()
li = line.strip()
print(li)
mibig_file.close()

# %%
k = "hola"
"h" in k

# %%
def std_highlighter(x):
    style_lt = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    style_gt = "background-color: #C04000; color: black; font-weight: bold; border: solid; text-align:center;"
    gt_std = x > x.mean() + x.std()
    return [style_gt if i else style_lt for i in gt_std]

def std2_highlighter(x):
    style_lt = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    style_gt = "background-color: #C04000; color: black; font-weight: bold; border: solid; text-align:center;"
    gt_std = x > x.mean() + 2*x.std()
    return [style_gt if i else style_lt for i in gt_std]

def mean_highlighter(x):
    style_lt = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    style_gt = "background-color: #C04000; color: black; font-weight: bold; border: solid; text-align:center;"
    gt_mean = x > x.mean()
    return [style_gt if i else style_lt for i in gt_mean]
def median_highlighter(x):
    style_lt = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    style_gt = "background-color: #C04000; color: black; font-weight: bold; border: solid; text-align:center;"
    gt_median = x > x.mean()
    return [style_gt if i else style_lt for i in gt_median]

def mode_highlighter(x):
    import statistics as st
    style_lt = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    style_gt = "background-color: #C04000; color: black; font-weight: bold; border: solid; text-align:center;"
    gt_mode = x > st.mode(x)
    return [style_gt if i else style_lt for i in gt_mode]

def genomes_highlighter(x):
    style_genome = "background-color: white; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    return [style_genome for i in x]
headers = {
    'selector': 'th.col_heading',
    'props': "background-color: OldLace; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
} 
def apply_highlighter2(df_heat,function, style_highlighter, headers_style):
    return df_heat.style.apply(function,subset=["fam_1", "fam_2"]).apply(style_highlighter, subset="orgs_ids").hide(axis="index").set_table_styles([headers_style], overwrite = False)

# %%
def make_heat_map(criteria):
    import json
    
    json_file_Expfams = open(CTS.EXP_FAMS_JSON, "r")
    exp_fam_dictio = json.load(json_file_Expfams)
    json_file_Expfams.close()
    
    json_file_org = open(CTS.ORGS_IDS_NMS, "r")
    orgs_ids_dict = json.load(json_file_org)
    orgs_ids_list = list(orgs_ids_dict.keys())
    json_file_org.close()
    
    json_file_fams = open(CTS.FAMILIES, "r")
    fams_dict = json.load(json_file_fams)
    families = list(fams_dict.keys())
    json_file_fams.close()
    
    Dictio_DF = {"orgs_ids": orgs_ids_list}
    for fam in families:
        Dictio_DF[fam] = []
    for org in Dictio_DF["orgs_ids"]:
        for key in exp_fam_dictio:
            if org in key:
                fmly = key.split("|")[0]
                Dictio_DF[fmly].append(len(exp_fam_dictio[key]))
    
    #Dictio_DF
    DF_heat = pd.DataFrame.from_dict(Dictio_DF)
    #for indx in DF_heat.index:
    #    Id = DF_heat["organisms"][indx]
    #    DF_heat.at[indx,"organisms"] = orgs_ids_dict[Id]
    
    
    #DF_heat
    headers_style = {
    'selector': 'th.col_heading',
    'props': "background-color: OldLace; color: black; font-weight: bold; border: solid; text-align: center; font-size:1.2em;"
    }
    if criteria == "mean":
        return apply_highlighter2(DF_heat,mean_highlighter, genomes_highlighter, headers_style)
    elif criteria == "median":
        return apply_highlighter2(DF_heat,median_highlighter, genomes_highlighter, headers_style)
    elif criteria == "mean + std":
        return apply_highlighter2(DF_heat,std_highlighter, genomes_highlighter, headers_style)
    elif criteria == "mean + 2*std":
        return apply_highlighter2(DF_heat,std2_highlighter, genomes_highlighter, headers_style)
    elif criteria == "mode":
        return apply_highlighter2(DF_heat,mode_highlighter, genomes_highlighter, headers_style)
    else: 
        return print(f"{criteria} is not a valid criteria\n")

# %%
make_heat_map("mean + std")

# %% [markdown]
# ## MUSCLE:

# %%
import evo_helpers as hlp
import evo_constants as CTS
from Bio.Align.Applications import MuscleCommandline

# %%
muscle_exe = "/home/luisyovanny/muscle5.1.linux_intel64"

# %%
in_file = CTS.EXPANDED_FAMS + "expanded_fam_1.fasta"
out_file = CTS.MUSCLE_OUTPUT + "MUSCLE_" + "expanded_fam_1.fasta"
#muscle_cline = MuscleCommandline(muscle_exe, input=in_file, out=out_file)

# %%
#muscle_cline = MuscleCommandline(muscle_exe, input = in_file, out = out_file)
import subprocess
#subprocess.call('/home/csar/muscle_v5/muscle5.1.linux_intel64 -align %s -output %s'%(in_file,out_file))

# %%
#import os
#os.popen('/home/csar/muscle_v5/muscle5.1.linux_intel64 -align %s -output %s'%(in_file,out_file))

# %%
import subprocess
subprocess.run(["/home/luisyovanny/muscle5.1.linux_intel64", "-align", in_file, "-output", out_file])
